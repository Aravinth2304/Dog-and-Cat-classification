# %%
pip install --upgrade tensorflow keras
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from keras import Model
from keras.layers import Dense, GlobalAveragePooling2D, Input
from keras.applications.mobilenet import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.optimizers import Adam
from keras.utils import load_img, img_to_array
from keras.applications.vgg16 import preprocess_input, decode_predictions, VGG16
from keras.models import load_model

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
train_generator = train_datagen.flow_from_directory("C:/Users/ARAVINTH1/Downloads/DOG_CAT",target_size=(224,224),color_mode='rgb',batch_size=32,class_mode='categorical',shuffle=True)
# Out:
# Found 300 images belonging to 2 classes.

# %%
train_generator.class_indices.values()
NO_CLASSES = len(train_generator.class_indices.values())
train_generator.class_indices.values()
# Out:
# dict_values([0, 1])

# %%
model = VGG16(include_top=False, input_shape=(224, 224, 3))
x = model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dense(1024, activation='relu')(x)
x = Dense(512, activation='relu')(x)

# final layer with softmax activation
preds = Dense(NO_CLASSES, activation='softmax')(x)
model = Model(model.input, preds)

# don't train first 19 layers
for layer in model.layers[:19]:
 layer.trainable = False

# train rest of the layers - 19 onwards
for layer in model.layers[19:]:
 layer.trainable = True

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x=train_generator,batch_size= 1,verbose= 1,epochs= 20)
# Out:
# C:\Users\ARAVINTH1\anaconda3\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.5865 - loss: 6.0611
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.9419 - loss: 0.1604
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 0.9855 - loss: 0.0347
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 4s/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 4s/step - accuracy: 1.0000 - loss: 4.4096e-04
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 44s 4s/step - accuracy: 1.0000 - loss: 1.6492e-04
# Epoch 7/20
# ...

# %%
class_dictionary = {0: 'Cat', 1: 'Dog'}
imgtest = cv2.imread("C:/Users/ARAVINTH1/Downloads/DOG_CAT/dog/dog.9603.jpg", cv2.IMREAD_UNCHANGED)

if imgtest is None:
    print("Image not loaded. Please check the path.")
else:
    size = (224, 224)
    imgtest = cv2.resize(imgtest, size)

    plt.imshow(cv2.cvtColor(imgtest, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

    x = np.expand_dims(imgtest, axis=0)  
    x = tf.keras.applications.imagenet_utils.preprocess_input(x)  

    # Make the prediction
    predicted_prob = model.predict(x)
    print(predicted_prob)

    predicted_class = predicted_prob[0].argmax()
    print(f"Predicted class: {predicted_class}")
    print("Predicted Label: " + class_dictionary[predicted_class])
    print("============================\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# [[8.382031e-09 1.000000e+00]]
# Predicted class: 1
# Predicted Label: Dog
# ...
